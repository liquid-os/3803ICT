# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import re
from datetime import datetime as dt

# %% [markdown]
# #### Import the data and get a high-level picture

# %%
df = pd.read_csv('sales.csv')
df.head()
# Out:
#    order_id                       name           ordered_at  price  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54  $2.50         2
# 3     10001                        NaN  2018-01-01 12:14:54  $1.50         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54  $3.50         1
#
#   line_total
# 0     $10.50
# 1      $3.50
# 2      $5.00
# 3      $1.50
# 4      $3.50

# %%
df.shape
# Out:
# (29922, 6)

# %%
df.dtypes
# Out:
# order_id       int64
# name          object
# ordered_at    object
# price         object
# quantity       int64
# line_total    object
# dtype: object

# %% [markdown]
# #### TODO: Fix column datatypes
#
# Change ordered_at to datetime
#
# Change price and line_total to float

# %%
df['ordered_at'] = pd.to_datetime(df['ordered_at'])

# %%
df['line_total'] = (df['line_total']).replace('[\$]', '', regex=True)

# %%
df['price'] = (df['price']).replace('[\$]', '', regex=True)

# %%
df["price"] = pd.to_numeric(df["price"])

# %%
df["line_total"] = pd.to_numeric(df["line_total"])

# %%
df.dtypes
# Out:
# order_id               int64
# name                  object
# ordered_at    datetime64[ns]
# price                float64
# quantity               int64
# line_total           float64
# dtype: object

# %% [markdown]
# #### TODO: drop if duplicated or null

# %%
df[df.duplicated()].shape[0]
# Out:
# 538

# %%
df = df[df['name'].isnull() == False]

# %%
df.dropna()
# Out:
#        order_id                            name          ordered_at  price  \
# 0         10000        "ICE CREAM" Peanut Fudge 2018-01-01 11:30:00    3.5
# 1         10000        "ICE CREAM" Peanut Fudge 2018-01-01 11:30:00    3.5
# 2         10001              "SORBET" Raspberry 2018-01-01 12:14:54    2.5
# 4         10001       "CONE" Dipped Waffle Cone 2018-01-01 12:14:54    3.5
# 5         10002                 "SORBET" Lychee 2018-01-01 12:23:09    3.0
# 7         10002           "ICE CREAM" Earl Gray 2018-01-01 12:23:09    0.5
# 8         10003              "ICE CREAM" Matcha 2018-01-01 12:49:35    1.5
# 9         10004          "BEVERAGE" Iced Coffee 2018-01-01 13:22:59    2.5
# 10        10004             "BEVERAGE" Espresso 2018-01-01 13:22:59    2.5
# 11        10004           "ICE CREAM" Mint Chip 2018-01-01 13:22:59    1.5
# 12        10004             "CONE" Brownie Cone 2018-01-01 13:22:59    3.0
# ...

# %%
df.isnull().sum()
# Out:
# order_id      0
# name          0
# ordered_at    0
# price         0
# quantity      0
# line_total    0
# dtype: int64

# %%
df[df['name'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [order_id, name, ordered_at, price, quantity, line_total]
# Index: []

# %% [markdown]
# #### Sanity check for value ranges and to check assumptions

# %%
df[(df['price'] * df['quantity']) != df['line_total']].shape[0]
# Out:
# 29

# %%
df[df['line_total'] < 0].shape[0]
# Out:
# 282

# %% [markdown]
# #### TODO:
# Set line_total = price * quantity if different
# Remove if line total < 0

# %%
df.loc[df['price'] * df['quantity'] != df['line_total'], "line_total"] = df['price'] * df['quantity']

# %%
df = df[df['line_total'] >= 0]

# %%
df.describe()
# Out:
#            order_id         price      quantity    line_total
# count  28152.000000  28152.000000  28152.000000  28152.000000
# mean   14991.953396      2.510319      2.001705      5.027955
# std     2888.586572      1.059779      0.819506      3.085916
# min    10000.000000      0.500000      1.000000      0.500000
# 25%    12500.750000      1.500000      1.000000      2.500000
# 50%    14967.500000      2.500000      2.000000      4.500000
# 75%    17506.000000      3.500000      3.000000      7.500000
# max    19999.000000      4.000000      3.000000     12.000000

# %% [markdown]
# #### TODO: Get value between "" in name and put it in category column

# %%
df['category'] = df.apply(lambda x: re.search(r'\"(.+?)\"', x['name']).group().replace('"', ''), axis=1)
df['name'] = df.apply(lambda x: re.sub(r'\"(.+?)\"', '', x['name']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-e44bb2945f3a> in <module>
# ----> 1 df['category'] = df.apply(lambda x: re.search(r'\"(.+?)\"', x['name']).group().replace('"', ''), axis=1)
#       2 df['name'] = df.apply(lambda x: re.sub(r'\"(.+?)\"', '', x['name']), axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ...

# %%
df.head()
# Out:
#    order_id                 name          ordered_at  price  quantity  \
# 0     10000         Peanut Fudge 2018-01-01 11:30:00    3.5         3
# 1     10000         Peanut Fudge 2018-01-01 11:30:00    3.5         1
# 2     10001            Raspberry 2018-01-01 12:14:54    2.5         2
# 4     10001   Dipped Waffle Cone 2018-01-01 12:14:54    3.5         1
# 5     10002               Lychee 2018-01-01 12:23:09    3.0         1
#
#    line_total   category
# 0        10.5  ICE CREAM
# 1         3.5  ICE CREAM
# 2         5.0     SORBET
# 4         3.5       CONE
# 5         3.0     SORBET

# %% [markdown]
# #### Analysis, finally!

# %%
f, ax = plt.subplots(figsize=(10, 6))
df.groupby('name')['line_total'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
f.autofmt_xdate()
plt.show()
